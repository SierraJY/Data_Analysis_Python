# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/seoul_childre.csv", encoding = "CP949")

# %%
df = df.loc[1:,['자치구명', '정원합계']]
df = df.groupby("자치구명").sum()
df = df.sort_values('정원합계', ascending=False)
df = df[1:]
print(df)
# Out:
#         정원합계
# 자치구명
# 강서    136682
# 송파    134020
# 은평    113128
# 노원    107319
# 구로    107109
# 강동    106065
# 양천    100211
# 영등포    95301
# 중랑     91351
# 강남     90580
# 관악     90111
# 성북     89679
# 서초     80872
# 도봉     78954
# 동작     75962
# 마포     75851
# 동대문    73218
# 광진     69583
# 강북     68307
# 성동     65008
# 금천     64689
# 서대문    58007
# 용산     43120
# 종로     38252
# 중구     33788

# %%
y = list(df.index)
x = list(df.values)
x = [i[0] for i in x]
print(x)
print(y)
# Out:
# [136682, 134020, 113128, 107319, 107109, 106065, 100211, 95301, 91351, 90580, 90111, 89679, 80872, 78954, 75962, 75851, 73218, 69583, 68307, 65008, 64689, 58007, 43120, 38252, 33788]
# ['강서', '송파', '은평', '노원', '구로', '강동', '양천', '영등포', '중랑', '강남', '관악', '성북', '서초', '도봉', '동작', '마포', '동대문', '광진', '강북', '성동', '금천', '서대문', '용산', '종로', '중구']

# %%
sns.displot(x,kind = 'ecdf', marker = '^')
plt.text(33788, 0, '중구')
plt.text(43120, 0.1, '용산')
plt.text(58007, 0.125, '서대문')
plt.text(69583, 0.3, '광진')
plt.text(136682, 0.95, '강서')
plt.text(113128, 0.9, '은평')
plt.text(134020, 0.925, '송파')
plt.style.use('ggplot')
plt.title("<서울시 자치구별 어린이집 정원 분포 현황>")
plt.xlabel("어린이집 정원")
plt.text(130000, -0.1, '경험적 누적 분포')
# Out:
# Text(130000, -0.1, '경험적 누적 분포')
