# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/data_1245_20221106.csv",encoding =  "CP949")

# %%
one = df.iloc[0:28,1:2]
one.columns = ['22년 6월']


two = df.iloc[28:56,1:2]
two.columns = ['22년 5월']
two = two.set_axis(labels = [i for i in range(0,28)], axis = 0)

three = df.iloc[56:84,1:2]
three.columns = ['22년 4월']
three = three.set_axis(labels = [i for i in range(0,28)], axis = 0)

four = df.iloc[84:112,1:2]
four.columns = ['22년 3월']
four = four.set_axis(labels = [i for i in range(0,28)], axis = 0)

five = df.iloc[112:140,1:2]
five.columns = ['22년 2월']
five = five.set_axis(labels = [i for i in range(0,28)], axis = 0)

six = df.iloc[140:168,1:2]
six.columns = ['22년 1월']
six = six.set_axis(labels = [i for i in range(0,28)], axis = 0)

seven = df.iloc[168:196,1:2]
seven.columns = ['21년 12월']
seven = seven.set_axis(labels = [i for i in range(0,28)], axis = 0)

eight = df.iloc[196:224,1:2]
eight.columns = ['21년 11월']
eight = eight.set_axis(labels = [i for i in range(0,28)], axis = 0)

# %%
total = pd.concat([eight,seven,six,five,four,three,two,one], axis=1)

# %%
print(total)
Mean = [2953, 2749, 2713, 2619, 2410, 2432, 2433, 2279]
# Out:
#     21년 11월  21년 12월   22년 1월   22년 2월   22년 3월   22년 4월   22년 5월   22년 6월
# 0   2972.48  2648.80  2695.86  2625.98  2377.99  2493.10  2367.85  2335.22
# 1   2927.38  2719.53  2735.03  2620.44  2422.09  2490.80  2355.66  2293.61
# 2   2926.72  2706.79  2759.20  2596.58  2401.92  2473.11  2382.78  2268.40
# 3   2954.89  2743.80  2757.90  2604.24  2366.60  2461.45  2401.83  2288.78
# 4   2920.53  2744.52  2739.85  2550.08  2314.32  2439.62  2411.42  2249.56
# 5   2953.97  2744.09  2757.65  2592.27  2342.81  2452.25  2449.54  2235.07
# 6   2989.24  2729.68  2746.74  2596.56  2408.93  2451.50  2384.28  2236.16
# 7   2988.77  2676.54  2741.07  2610.81  2391.03  2435.27  2376.46  2213.12
# 8   2977.65  2704.48  2729.56  2644.51  2440.93  2415.53  2410.02  2218.09
# 9   2993.29  2747.71  2729.98  2677.57  2451.41  2412.96  2403.68  2237.44
# 10  3020.24  2771.93  2729.66  2680.46  2447.38  2403.69  2409.41  2249.95
# ...

# %%
sns.set_palette("pastel")
plt.rcParams['figure.figsize'] = [8, 8]
x = list(total.columns)
sns.boxplot(total.iloc[0:8])
plt.xticks(rotation=45)
plt.title("<8개월간 월별 코스피지수 분포>")

sns.lineplot(x = total.columns, y = Mean, marker = '^', color ='black', label = "월평균")
plt.text(6,3035,"**박스 중간선: 중앙값")
plt.show()
# Out:
# /Users/bagjuyeon/.local/share/virtualenvs/python_trash-y9cSlK3Z/lib/python3.9/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
