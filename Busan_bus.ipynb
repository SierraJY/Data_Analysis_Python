# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/busan_Bus.csv",  encoding = "CP949")

# %%
print(df)
# Out:
#        역번호       역명         년월일 요일  구분    합계  01시-02시  02시-03시  03시-04시  \
# 0       95  다대포해수욕장  2022-01-01  토  승차  5142        0        0        0
# 1       95  다대포해수욕장  2022-01-01  토  하차  4430        0        0        0
# 2       95  다대포해수욕장  2022-01-02  일  승차  3429        0        0        0
# 3       95  다대포해수욕장  2022-01-02  일  하차  2992        0        0        0
# 4       95  다대포해수욕장  2022-01-03  월  승차  4323        0        0        0
# ...    ...      ...         ... ..  ..   ...      ...      ...      ...
# 54427  414     안  평  2022-08-29  월  하차  2098        0        0        0
# 54428  414     안  평  2022-08-30  화  승차  2069        0        0        0
# 54429  414     안  평  2022-08-30  화  하차  1928        0        0        0
# 54430  414     안  평  2022-08-31  수  승차  1831        0        0        0
# 54431  414     안  평  2022-08-31  수  하차  1723        0        0        0
#
#        04시-05시  ...  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  \
# ...

# %%
df = df.sum()

# %%
df = df[6:]

# %%
print(df)
# Out:
# 01시-02시       12922
# 02시-03시        9756
# 03시-04시        6173
# 04시-05시      110123
# 05시-06시     3582355
# 06시-07시     8153068
# 07시-08시    17490388
# 08시-09시    31785141
# 09시-10시    21775822
# 10시-11시    19680703
# 11시-12시    21346375
# 12시-13시    22664739
# 13시-14시    23463742
# 14시-15시    22924440
# 15시-16시    24465654
# 16시-17시    27015137
# 17시-18시    30809419
# 18시-19시    34616954
# 19시-20시    17855893
# 20시-21시    13287600
# 21시-22시    11722957
# 22시-23시     8226483
# 23시-24시     4689705
# 24시-01시      861166
# dtype: object

# %%
x = np.linspace(0,np.pi*2,24)
y = list(df.values)
y = [i / 1000000 for i in (y)]
print(y)
# Out:
# [0.012922, 0.009756, 0.006173, 0.110123, 3.582355, 8.153068, 17.490388, 31.785141, 21.775822, 19.680703, 21.346375, 22.664739, 23.463742, 22.92444, 24.465654, 27.015137, 30.809419, 34.616954, 17.855893, 13.2876, 11.722957, 8.226483, 4.689705, 0.861166]

# %%
plt.axes(polar=True)
plt.plot(x,y)

ticks = [str(i) + '시' for i in range(1,25)]
ticks.append('')
print(ticks)
plt.xticks(np.linspace(0,np.pi*2, 25), ticks)

plt.title("    <부산교통공사_시간대별 승하차인원>       단위 10만명")
plt.style.use('ggplot')
plt.show()
# Out:
# ['1시', '2시', '3시', '4시', '5시', '6시', '7시', '8시', '9시', '10시', '11시', '12시', '13시', '14시', '15시', '16시', '17시', '18시', '19시', '20시', '21시', '22시', '23시', '24시', '']
