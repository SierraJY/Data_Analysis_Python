# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/seoul_Language.csv", encoding = "CP949")

# %%
kor_df = list(df['한국어'])
eng_df = list(df['영어'])
jap_df = list(df['일본어'])
rus_df = list(df['러시아어'])
chin_df = list(df['중국어'])

# %%
print(kor_df)
print(rus_df)
print(chin_df)
# Out:
# [56, 68, 63, 79, 51, 58, 53, 34, 42, 79, 37, 57, 44, 66, 98, 64, 62, 59, 60, 64, 85, 112, 69, 73, 547, 109, 83, 72, 81, 122, 60, 102, 91, 76, 72, 211, 246, 114, 79]
# [261, 297, 308, 285, 378, 327, 376, 260, 354, 330, 389, 417, 353, 380, 328, 354, 370, 405, 409, 298, 501, 324, 419, 382, 591, 437, 619, 654, 578, 590, 625, 501, 462, 296, 469, 591, 609, 365, 617]
# [243, 275, 168, 194, 206, 203, 250, 164, 172, 239, 170, 205, 215, 525, 510, 278, 226, 192, 217, 131, 159, 203, 266, 209, 594, 279, 330, 250, 237, 477, 270, 279, 178, 200, 209, 182, 211, 230, 197]

# %%
plt.subplot(3,1,1)
plt.axis('off')
sns.kdeplot(x=kor_df, fill = True, bw_method = .15, color = "red", label ="한국어")
plt.subplot(3,1,2)
plt.axis('off')
sns.kdeplot(x=rus_df, fill = True, bw_method = .15, label = "러시아어")
plt.subplot(3,1,3)
plt
sns.kdeplot(x=chin_df, fill = True, bw_method = .15, label = "중국어")
plt.legend()
plt.title("서울글로벌센터 월별 언어별 상담실적")
plt.xlabel("상담실적(횟수)")
plt.show()
