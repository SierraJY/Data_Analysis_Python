# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import squarify
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
sam = ['삼성전자', '삼성바이오로직스', '삼성SDI', '삼성물산','삼성화재']
sam_p = [3546051,619926, 504044, 225199, 99855]
samsung_colors = ['blue', 'royalblue', 'cornflowerblue', 'lightblue','lightsteelblue']

lg = ['LG에너지솔루션', 'LG화학', 'LG전자', 'LG생활건강','']
lg_p = [1385280,487087, 144992, 86681, 78152]
lg_colors = ['red', 'tomato', 'salmon', 'lightcoral','mistyrose']

sk = ['sk하이닉스', 'sk이노베이션', 'sk텔레콤', 'sk바이오사이언스',' ']
sk_p = [615162, 164126, 110730, 62349, 51777]
sk_colors = ['darkorange', 'orange', 'moccasin', 'papayawhip','floralwhite']

# %%
samsung_colors = ['blue', 'royalblue', 'cornflowerblue', 'lightblue','lightsteelblue']
lg_colors = ['red', 'tomato', 'salmon', 'lightcoral','mistyrose']
sk_colors = ['darkorange', 'orange', 'moccasin', 'papayawhip','floralwhite']

plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots(2,3)

plt.subplot(grid[0, 0:])
plt.title("<3대그룹 5개 계열사 시가총액 비중>")
squarify.plot(sam_p, label=sam, color =samsung_colors,bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.axis('off')
plt.text(55,-10,"<삼성>",fontsize=15)

plt.subplot(grid[1, 0:2])
squarify.plot(lg_p, label=lg, color =lg_colors,bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.axis('off')
plt.text(85,90,'LG이노텍')
plt.title("<LG>",fontsize=15)
plt.subplot(grid[1, 2:3])

squarify.plot(sk_p, label=sk, color =sk_colors,bar_kwargs=dict(linewidth=3, edgecolor="#eee"))
plt.axis('off')
plt.title("<SK>",fontsize=15)
plt.text(90,100,'sk스퀘어')
plt.show()
# Out:
# /var/folders/sr/_tx5wvc53ql14nhd12zyk1qh0000gn/T/ipykernel_6998/512986115.py:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[0, 0:])
# /var/folders/sr/_tx5wvc53ql14nhd12zyk1qh0000gn/T/ipykernel_6998/512986115.py:14: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1, 0:2])
# /var/folders/sr/_tx5wvc53ql14nhd12zyk1qh0000gn/T/ipykernel_6998/512986115.py:19: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(grid[1, 2:3])
