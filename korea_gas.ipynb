# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/korea_gas.csv", encoding = "CP949")

# %%
print(df)
# Out:
#       연도  월      생산량
# 0   2016  1  4288593
# 1   2016  2  3592400
# 2   2016  3  3201669
# 3   2016  4  2135286
# 4   2016  5  1989360
# ..   ... ..      ...
# 63  2021  4  3296135
# 64  2021  5  2972416
# 65  2021  6  2943359
# 66  2021  7  3264511
# 67  2021  8  2942282
#
# [68 rows x 3 columns]

# %%
sns.set_style("darkgrid")
matplotlib.rcParams['font.family'] = "AppleGothic"
plt.title("연도별 천연가스 월 생산량     단위:10만 톤")

sns.boxplot(x = df["연도"], y = df["생산량"], data = df)
# Out:
# <AxesSubplot: title={'center': '연도별 천연가스 월 생산량     단위:10만 톤'}, xlabel='연도', ylabel='생산량'>
