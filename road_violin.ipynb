# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['axes.unicode_minus'] = False
matplotlib.rcParams['font.family'] = "AppleGothic"

# %%
df = pd.read_csv("/Users/bagjuyeon/Desktop/python_trash/도로교통공단_도로종류별 월별 교통사고 통계_20211231.csv", encoding = "CP949")
df = df.iloc[:48,:3]

# %%
print(df)
# Out:
#       도로종류  발생월  사고건수
# 0     일반국도    1  1272
# 1     일반국도    2  1332
# 2     일반국도    3  1498
# 3     일반국도    4  1630
# 4     일반국도    5  1638
# 5     일반국도    6  1654
# 6     일반국도    7  1605
# 7     일반국도    8  1538
# 8     일반국도    9  1651
# 9     일반국도   10  1803
# 10    일반국도   11  1793
# 11    일반국도   12  1569
# 12     지방도    1   981
# 13     지방도    2   993
# 14     지방도    3  1142
# 15     지방도    4  1153
# 16     지방도    5  1208
# 17     지방도    6  1170
# 18     지방도    7  1340
# 19     지방도    8  1179
# 20     지방도    9  1155
# 21     지방도   10  1280
# 22     지방도   11  1280
# 23     지방도   12  1110
# 24  특별광역시도    1  6180
# 25  특별광역시도    2  5891
# 26  특별광역시도    3  6752
# 27  특별광역시도    4  6942
# 28  특별광역시도    5  6890
# 29  특별광역시도    6  6939
# 30  특별광역시도    7  6932
# 31  특별광역시도    8  6436
# 32  특별광역시도    9  6621
# 33  특별광역시도   10  6874
# 34  특별광역시도   11  6981
# 35  특별광역시도   12  6667
# 36      시도    1  4929
# 37      시도    2  4782
# 38      시도    3  5325
# 39      시도    4  5678
# ...

# %%
plt.title("도로종류별 월 사고건수 분포")
sns.violinplot(x = "도로종류", y = "사고건수", data = df)
# Out:
# <AxesSubplot: title={'center': '도로종류별 월 사고건수 분포'}, xlabel='도로종류', ylabel='사고건수'>
